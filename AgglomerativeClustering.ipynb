# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('dataclustering.csv')
aa = data['x']
bb = data['y']

df = pd.DataFrame ({
    'x' : aa,
    'y' : bb
})

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
dendrogram = sch.dendrogram(sch.linkage(df,method='ward'))

# %%
plt.scatter(df['x'],df['y'])

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')

# %%
y_hc=hc.fit_predict(df)

# %%
dendrogram = sch.dendrogram(sch.linkage(y_hc,method='ward'))

# %%
print(y_hc)
# Out:
# [1 1 3 1 1 1 1 0 3 3 2 2 1 2 2 0 2 1 1 3 0 0 1 2 3 0 2 0 1 0 0 3 0 3 0 3 3
#  0 2 0 0 0 0 1 2 3 0 3 1 1 2 0 2 2 0 0 0 0 1 3 3 1 2 3 3 1 0 2 1 3 2 3 1 2
#  0 0 0 3 2 0 3 2 0 0 2 0 3 1 1 2 0]

# %%
plt.scatter(df['x'],df['y'], c=y_hc, cmap='rainbow')
